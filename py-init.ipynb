# %% [markdown]
# # Analyse de données via Pandas
#
# > Cellule 1 importe "pandas" et affiche la version

# %%
import pandas as pd
# Affichage de la version
print("Pandas version ", pd.__version__)
# Out:
# Pandas version  2.3.3

# %% [markdown]
# ## Lire le fichier csv
#
# La fonction pd.read_csv() charge un fichier et le transforme en **DataFrame**
#
# > Un *DataFrame* est un tableau de données que Python peut manipuler
#
# ```python
# datas = pd.read_csv(<filepath>)
# ```

# %%
datas = pd.read_csv("sample_data.csv")

print(type(datas))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Déterminer le nombre de lignes lues, le nombre de colonnes
#
# - **shape** est un **Tuple** au sens Python du terme : une liste *(lignes, colonnes)*
# - l'accès aux données d'un Tuple se fait par la notation *[]*

# %%
nb_lignes = datas.shape[0]
nb_colonnes = datas.shape[1]
print("Lines number : ", nb_lignes)
print("Columns number : ", nb_colonnes)
print("Complete dimensions : ", datas.shape)
# Out:
# Nombre de lignes :  200
# Nombre de colonnes :  6
# Complete dims :  (200, 6)

# %% [markdown]
# ## Récupérer les données d'en-tête (les noms des colonnes)
#
# - DataFrame.columns : Retourne le nom des colonnes
#
# ## Afficher n lignes pour contrôle
#
# - DataFrame.head(n)
#
# ## Connaître le type des colonnes
#
# - DataFrame.dtypes

# %%
print("Colonnes")
print(datas.columns)

print("Aperçu des données")
print(datas.head(10))

print("Types des colonnes")
print(datas.dtypes)
# Out:
# Colonnes
# Index(['feature_a', 'feature_b', 'feature_c', 'feature_d', 'feature_e',
#        'target'],
#       dtype='object')
# Aperçu des données
#    feature_a   feature_b  feature_c  feature_d  feature_e    target
# 0  54.967142  107.155747   0.414820          8   5.779494  classe_2
# 1  48.617357  111.215691   0.273407          9   0.304163  classe_2
# 2  56.476885  121.661025   0.056375          5   1.043073  classe_3
# 3  65.230299  121.076041   0.864722          3   0.783095  classe_2
# 4  47.658466   72.446613   0.812901          5   0.181875  classe_1
# 5  47.658630   81.243499   0.999718          5   2.006099  classe_2
# 6  65.792128  110.300705   0.996637          5   2.662890  classe_1
# 7  57.674347  110.275719   0.555432          3   3.769436  classe_1
# 8  45.305256  110.300954   0.768987          4   0.261988  classe_2
# 9  55.425600  177.054630   0.944766          9   4.182123  classe_3
# Types des colonnes
# feature_a    float64
# feature_b    float64
# feature_c    float64
# feature_d      int64
# feature_e    float64
# target        object
# dtype: object

# %% [markdown]
# ## Résumé statistique du DataFrame (cumuls, moyennes, écarts-types, ...)
#
# - DataFrame.describe()

# %%
datas.describe()
